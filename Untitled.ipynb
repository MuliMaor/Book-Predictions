# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("books_final.csv")
df.head()
# Out:
#    Unnamed: 0                                              Title Genre  \
# 0           0                                     Ways of Seeing   art
# 1           1                                   The Story of Art   art
# 2           2     The New Drawing on the Right Side of the Brain   art
# 3           3  Steal Like an Artist: 10 Things Nobody Told Yo...   art
# 4           4                                     Wall and Piece   art
#
#           Author  Pages  Publish_Date  language  Num_Reviews  Num_Ratings  \
# 0    John Berger  176.0        1990.0         1         1912       302885
# 1  E.H. Gombrich  688.0        1995.0         1         1102       355674
# 2  Betty Edwards  291.0        1999.0         1          858       321756
# 3   Austin Kleon  160.0        2012.0         1         6940       238078
# 4         Banksy  240.0        2006.0         1          893       214249
#
#    Rating
# 0    3.90
# 1    3.95
# 2    3.87
# 3    3.95
# 4    3.85

# %%
df['language'].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='language'>

# %%
df['Author'].value_counts().head(10).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
pd.cut(df['Rating'], bins=5).value_counts().plot(kind = "line")
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['Rating'], bins=4)
# Out:
# (array([   9.,  451., 5748., 1553.]),
#  array([2.53  , 3.0925, 3.655 , 4.2175, 4.78  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(df['Publish_Date'], bins=5)
# Out:
# (array([1.000e+00, 2.000e+00, 2.700e+01, 6.360e+02, 7.095e+03]),
#  array([1887., 1914., 1941., 1968., 1995., 2022.]),
#  <BarContainer object of 5 artists>)

# %%
pd.cut(df['Publish_Date'], bins=3).value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df.Publish_Date, df.Rating)

# %%
plt.scatter(df.Num_Reviews, df.Rating)

# %%
plt.scatter(df.Num_Ratings, df.Rating)

# %%
plt.scatter(df.Num_Reviews, df.Num_Ratings)
